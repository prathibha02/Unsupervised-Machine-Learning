# %%
# Initial imports
import pandas as pd
from pathlib import Path
from sklearn.preprocessing import StandardScaler
from sklearn.decomposition import PCA
from sklearn.cluster import KMeans
from sklearn.manifold import TSNE
import matplotlib.pyplot as plt
import seaborn as sns

# %%
file_path = './Resources/myopia_cleaned.csv'

# %%
df = pd.read_csv(file_path)

# %%
# Initialize PCA model
pca = PCA(n_components=0.90)

# Get two principal components for the data.
myopia_pca = pca.fit_transform(df)

# %%
# Transform PCA data to a DataFrame
df_myopia_pca = pd.DataFrame(
    data=myopia_pca,columns=["principal component 1", "principal component 2","principal component 3"]
)
df_myopia_pca.head()
# Out:
#    principal component 1  principal component 2  principal component 3
# 0              12.138059              31.636212              -4.526625
# 1             -15.268363              -6.095695               1.207074
# 2             -11.662239               3.755105               2.808212
# 3              11.235886               4.012566              -8.179565
# 4             -22.446506               4.580916              -1.817501

# %%
#Fetch the explained variance
pca.explained_variance_ratio_
# Out:
# array([0.72557249, 0.16081428, 0.07227215])

# %%
tsne = TSNE(learning_rate=340)
tsne_features = tsne.fit_transform(df_myopia_pca)
# Out:
# C:\Users\pravi\anaconda3\envs\PythonData\lib\site-packages\sklearn\manifold\_t_sne.py:800: FutureWarning: The default initialization in TSNE will change from 'random' to 'pca' in 1.2.
#   warnings.warn(

# %%
# Check that dimensions have been reduced to two
tsne_features.shape
# Out:
# (618, 2)

# %%
# Results colored by target value
plt.scatter(tsne_features[:,0], tsne_features[:,1], c=tsne_features[:,1])
plt.show()

# %% [markdown]
# ##### When we look at both the analyses, Cluster Analysis with K Means and Dimension Reduction by PCA method, we find that it's hard to see the clusters clearly. So it is very hard to determine what cluster the patient belongs to, Myopic or not
